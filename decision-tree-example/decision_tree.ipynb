# %%
#importing data analysis libraries and training dataset 
import pandas as pd 
import numpy as np 
df_training = pd.read_csv('udemy_entrenamiento.csv')
df_test = pd.read_csv('udemy_prueba.csv')
df_training.head(10) 
df_test.head(10)
# Out:
#       id                                              title  \
# 0  11088  Desarrolla Juegos 2D en Unity hasta publicarlo...
# 1  11089  React Native: Aplicaciones nativas para IOS y ...
# 2  11090  Introducción a Internet de las cosas con Micro...
# 3  11091          Identifica y construye a tu cliente ideal
# 4  11092  Análisis de Procesos para líderes y jefes de p...
# 5  11093  Diploma Acreditado de Aromaterapia 1:Aromatera...
# 6  11094  Inglés para Niños - Nivel 10 Jumbo (Genki Inglés)
# 7  11095  Crea una pasarela de pagos con Laravel Cashier...
# 8  11096    Historia de MADRID: ITINERARIOS [Miguel Zorita]
# 9  11097  Los Verdaderos Secretos de TikTok : ¡Sea un In...
#
#                                             headline  is_practice_test_course  \
# 0  Juegos 2d todo lo necesario para crear un jueg...                    False
# 1  TypeScript, React Native CLI, Google y Apple m...                    False
# 2  Aprende como ingresar al mundo del Internet de...                    False
# 3  Construir las bases sólidas del perfil de clie...                    False
# 4  (Procesos, Decisiones y Costos con Teoría de R...                    False
# 5  Aprende todo lo que necesitas saber para compr...                    False
# 6  ¡Su Hij@ Puede Hablar Inglés Con Confianza de ...                    False
# 7  En este curso aprenderás a implementar una pas...                    False
# 8  Cada lección es un recorrido al libre por Madr...                    False
# 9  Conviértete en un Influencer TikTok: ¡Consigue...                    False
#
#    bestseller     captions  rating  num_published_lectures  \
# 0         NaN        es_ES     5.0                      21
# 1         NaN        es_LA     4.9                     380
# 2         NaN        es_ES     4.5                      32
# 3         NaN        es_ES     5.0                      31
# 4         NaN  es_MX,en_US     4.7                      15
# 5         NaN        es_LA     4.5                      52
# 6         NaN          NaN     5.0                       7
# 7         NaN        es_ES     4.8                      33
# 8         NaN        es_ES     5.0                      11
# 9         NaN        es_LA     3.4                      37
#
#    num_published_practice_tests locale  ... instructional_level_simple  \
# 0                             0  es_ES  ...               Principiante
# 1                             0  es_LA  ...          Todos los niveles
# 2                             0  es_ES  ...               Principiante
# 3                             0  es_ES  ...               Principiante
# 4                             0  es_MX  ...               Principiante
# 5                             0  es_LA  ...               Principiante
# 6                             0  es_VE  ...               Principiante
# 7                             0  es_ES  ...                 Intermedio
# 8                             0  es_ES  ...          Todos los niveles
# 9                             0  es_LA  ...          Todos los niveles
#
#   published_date last_update_date content_info_short          instructors  \
# 0     2021-03-21       2021-03-04            4 horas            116249520
# 1     2021-04-04       2021-06-14         43,5 horas             11767934
# 2     2021-04-06       2021-05-27          1,5 horas            136827143
# 3     2021-04-09              NaN            4 horas            135011368
# 4     2021-04-14       2021-05-04             1 hora             34396906
# 5     2021-04-25       2021-06-15            3 horas   18651996,152314142
# 6     2021-03-03       2021-03-11          1,5 horas             19036820
# 7     2021-03-04       2021-03-14          5,5 horas             35361316
# 8     2021-03-04       2021-04-25            4 horas  152410184,153887958
# 9     2021-03-04       2021-03-04          1,5 horas             28497888
#
#                               category                        subcategory  \
# 0               Informática y software  Desarrollo de juegos para móviles
# 1                           Desarrollo                 API de Google Maps
# 2               Informática y software                        MicroPython
# 3                             Negocios                           Personas
# 4                             Negocios             Gestión de operaciones
# 5                       Estilo de vida                       Aromaterapia
# 6  Enseñanzas y disciplinas académicas                      Idioma inglés
# 7                           Desarrollo             Procesamiento de pagos
# 8  Enseñanzas y disciplinas académicas                           Historia
# 9                            Marketing                Marketing en TikTok
#
#                                           objectives list_price discount_price
# 0  Aprenderás todos los conceptos básicos  para u...     $19.99            $12
# 1  React Native.Crear aplicaciones móviles nativa...     $89.99            $12
# 2  Controlar módulos ESP32 usando el lenguaje de ...     $34.99            $12
# 3  ¿Alguna vez te has preguntado cómo empresas co...     $59.99            $12
# 4  Analizar a fondo Procesos y Operaciones.Defini...     $24.99            NaN
# 5  Podrás trabajar con aceites esenciales y técni...     $94.99            $12
# 6  En el Nivel 10 Jumbo los estudiantes aprenderá...     $49.99            $12
# 7  Aprenderás a consumir la API de Stripe.Crear, ...     $94.99            $12
# 8  Historia de la ciudad de Madrid.Cada clase es ...     $24.99            $12
# 9  Aprenderás Rápidamente a convertirte en un Inf...     $94.99            $12
#
# [10 rows x 21 columns]

# %%
#data split
#step 1: separating response variable -target- from predictor variables -inputs-
target_training = df_training['bestseller'] 
#step 2: data cleansing and prepping
inputs_training =  df_training[['is_practice_test_course', 'captions', 'rating', 'num_published_lectures', 'num_published_practice_tests', 'locale', 'instructional_level_simple', 'published_date', 'last_update_date', 'category', 'list_price', 'discount_price']]
inputs_training[inputs_training.columns[10:]] = inputs_training[inputs_training.columns[10:]].replace('[\$]', '', regex=True).astype(float)
inputs_training['discount_price'] = inputs_training['discount_price'].fillna(0)
inputs_training[inputs_training.columns[[7,8]]] = inputs_training[inputs_training.columns[[7,8]]].replace('[\-]', '', regex=True).astype(float)
inputs_training['last_update_date'] = inputs_training['last_update_date'].fillna(0)
print(inputs_training.info())
inputs_training.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11087 entries, 0 to 11086
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   is_practice_test_course       11087 non-null  bool
#  1   captions                      9142 non-null   object
#  2   rating                        11087 non-null  float64
#  3   num_published_lectures        11087 non-null  int64
#  4   num_published_practice_tests  11087 non-null  int64
#  5   locale                        11087 non-null  object
#  6   instructional_level_simple    11082 non-null  object
#  7   published_date                11087 non-null  float64
#  8   last_update_date              11087 non-null  float64
#  9   category                      11087 non-null  object
#  10  list_price                    11087 non-null  float64
#  11  discount_price                11087 non-null  float64
# dtypes: bool(1), float64(5), int64(2), object(4)
# memory usage: 963.7+ KB
# None
# C:\Users\Juan\anaconda3\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# C:\Users\Juan\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Juan\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#    is_practice_test_course captions  rating  num_published_lectures  \
# 0                    False    es_LA     4.5                      58
# 1                    False    es_ES     4.1                      32
# 2                    False    es_ES     3.8                      76
# 3                    False    es_MX     4.0                      68
# 4                    False      NaN     4.6                     550
#
#    num_published_practice_tests locale instructional_level_simple  \
# 0                             1  es_LA          Todos los niveles
# 1                             0  es_ES               Principiante
# 2                             0  es_ES          Todos los niveles
# 3                             0  es_MX                 Intermedio
# 4                             0  es_MX          Todos los niveles
#
#    published_date  last_update_date        category  list_price  \
# 0      20120126.0        20210519.0          Música       34.99
# 1      20120610.0        20151217.0  Estilo de vida       99.99
# 2      20120703.0        20200228.0       Marketing       94.99
# 3      20120831.0        20190908.0      Desarrollo       19.99
# 4      20120902.0        20210304.0      Desarrollo       29.99
#
#    discount_price
# 0            12.0
# 1             0.0
# 2            12.0
# 3            12.0
# 4            12.0

# %%
#label encoding inputs: find object datatype columns and create list
objList = inputs_training.select_dtypes(include = "object").columns
#print (objList)

#Label Encoding for object to numeric conversion, start with inputs
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for feat in objList:
    inputs_training[feat] = le.fit_transform(inputs_training[feat].astype(str))

print (inputs_training.info())

#then le target
le = LabelEncoder()
target_training_dummy= pd.DataFrame(le.fit_transform(target_training))
target_training_dummy.columns=['bestseller']

#inputs_training.head()
#label encoding alternative method:  (creates dummy variables for every category, not useful)
'''from sklearn.preprocessing import LabelEncoder
cat_cols = [
    f for f in inputs_training.columns if inputs_training[f].dtype == 'object'
]
inputs_training_dummies = pd.get_dummies(inputs_training, columns=cat_cols)'''
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11087 entries, 0 to 11086
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   is_practice_test_course       11087 non-null  bool
#  1   captions                      11087 non-null  int32
#  2   rating                        11087 non-null  float64
#  3   num_published_lectures        11087 non-null  int64
#  4   num_published_practice_tests  11087 non-null  int64
#  5   locale                        11087 non-null  int32
#  6   instructional_level_simple    11087 non-null  int32
#  7   published_date                11087 non-null  float64
#  8   last_update_date              11087 non-null  float64
#  9   category                      11087 non-null  int32
#  10  list_price                    11087 non-null  float64
#  11  discount_price                11087 non-null  float64
# dtypes: bool(1), float64(5), int32(4), int64(2)
# memory usage: 790.5 KB
# None
# C:\Users\Juan\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# "from sklearn.preprocessing import LabelEncoder\ncat_cols = [\n    f for f in inputs_training.columns if inputs_training[f].dtype == 'object'\n]\ninputs_training_dummies = pd.get_dummies(inputs_training, columns=cat_cols)"

# %%
#train model & split data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs_training,target_training_dummy,test_size=0.2)
#import and apply decision tree
from sklearn import tree
model = tree.DecisionTreeClassifier()
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.763751127141569

# %%
#insert test data
df_test_real = df_test.drop('bestseller', axis='columns')
df_test_real =  df_test_real[['is_practice_test_course', 'captions', 'rating', 'num_published_lectures', 'num_published_practice_tests', 'locale', 'instructional_level_simple', 'published_date', 'last_update_date', 'category', 'list_price', 'discount_price']]
df_test_real[df_test_real.columns[10:]] = df_test_real[df_test_real.columns[10:]].replace('[\$]', '', regex=True).astype(float)
df_test_real['discount_price'] = df_test_real['discount_price'].fillna(0)
df_test_real[df_test_real.columns[[7,8]]] = df_test_real[df_test_real.columns[[7,8]]].replace('[\-]', '', regex=True).astype(float)
df_test_real['last_update_date'] = df_test_real['last_update_date'].fillna(0)
print(df_test_real.info())
df_test_real.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   is_practice_test_course       239 non-null    bool
#  1   captions                      188 non-null    object
#  2   rating                        239 non-null    float64
#  3   num_published_lectures        239 non-null    int64
#  4   num_published_practice_tests  239 non-null    int64
#  5   locale                        239 non-null    object
#  6   instructional_level_simple    239 non-null    object
#  7   published_date                239 non-null    float64
#  8   last_update_date              239 non-null    float64
#  9   category                      239 non-null    object
#  10  list_price                    239 non-null    float64
#  11  discount_price                239 non-null    float64
# dtypes: bool(1), float64(5), int64(2), object(4)
# memory usage: 20.9+ KB
# None
#    is_practice_test_course     captions  rating  num_published_lectures  \
# 0                    False        es_ES     5.0                      21
# 1                    False        es_LA     4.9                     380
# 2                    False        es_ES     4.5                      32
# 3                    False        es_ES     5.0                      31
# 4                    False  es_MX,en_US     4.7                      15
#
#    num_published_practice_tests locale instructional_level_simple  \
# 0                             0  es_ES               Principiante
# 1                             0  es_LA          Todos los niveles
# 2                             0  es_ES               Principiante
# 3                             0  es_ES               Principiante
# 4                             0  es_MX               Principiante
#
#    published_date  last_update_date                category  list_price  \
# 0      20210321.0        20210304.0  Informática y software       19.99
# 1      20210404.0        20210614.0              Desarrollo       89.99
# 2      20210406.0        20210527.0  Informática y software       34.99
# 3      20210409.0               0.0                Negocios       59.99
# 4      20210414.0        20210504.0                Negocios       24.99
#
#    discount_price
# 0            12.0
# 1            12.0
# 2            12.0
# 3            12.0
# 4             0.0

# %%
#label encoding for test data: find object datatype columns and create list
objList_test = df_test_real.select_dtypes(include = "object").columns
#print (objList)

#Label Encoding for object to numeric conversion, start with inputs
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for feat in objList:
    df_test_real[feat] = le.fit_transform(df_test_real[feat].astype(str))

print (df_test_real.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   is_practice_test_course       239 non-null    bool
#  1   captions                      239 non-null    int32
#  2   rating                        239 non-null    float64
#  3   num_published_lectures        239 non-null    int64
#  4   num_published_practice_tests  239 non-null    int64
#  5   locale                        239 non-null    int32
#  6   instructional_level_simple    239 non-null    int32
#  7   published_date                239 non-null    float64
#  8   last_update_date              239 non-null    float64
#  9   category                      239 non-null    int32
#  10  list_price                    239 non-null    float64
#  11  discount_price                239 non-null    float64
# dtypes: bool(1), float64(5), int32(4), int64(2)
# memory usage: 17.2 KB
# None

# %%
#predict values with test data
model.predict(df_test_real) #here we get predicted values
#create model object
predictions = model.predict(df_test_real)
# finally, insert new course data (ids), append it to new dataframe with predicted values and export it to csv for submission 
df_solucion = pd.read_csv('udemy_ejemplo_solucion.csv')
df_solucion_2 = df_solucion['id']
predictions_df=pd.DataFrame(predictions)
predictions_new_df=predictions_df.join(df_solucion_2)
predictions_new_df=predictions_new_df.iloc[:, [1,0]]
predictions_new_df.columns=['id','bestseller']
predictions_new_df
predictions_new_df.to_csv('predictions_udemy_sklearn.csv', index=False,header=True)
